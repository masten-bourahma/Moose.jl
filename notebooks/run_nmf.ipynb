# %%
# activate environment
using Pkg
Pkg.activate("../.")
#Pkg.status()

# %%
# include "nmf.jl" script 
include("../src/Moosenmf.jl")
using .Moosenmf

# %% [markdown]
# ## **Run NMF, guide notebook**

# %% [markdown]
# ### **1. Load your data & store them in  an `NMF` struct:**
# Here my spectra and standard devations matrices are stored in an `.h5` file, I'll use the `HDF5` package to read them.

# %%
using HDF5
file = h5open("../data/")

# %%
X = read(file, "")
Σ = read(file, "")


close(file);

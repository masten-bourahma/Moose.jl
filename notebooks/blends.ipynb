# %% [markdown]
# ### This notebooks shows how `Moose` can detect blended spectra
# spectrum number 7 in the data sample is blended

# %%
using Pkg
Pkg.activate("..")
using Revise
using Moose
# Out:
#   Activating project at `~/Desktop/packages/Moose`

# %%
wgrid = Γgrid(λmin = 4700f0, δζ = 0.0005f0)
basis = Basis(wgrid)

# %%
path = "../data/spectra_sample/"
data  = leggere_fits(path)
